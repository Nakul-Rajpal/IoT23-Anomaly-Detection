# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
# 42 seed results
precision = np.array([0.9995, 0.9991, 0.996, 0.9974, 0.9972, 0.9893, 0.9839, 0.9834, 0.9648, 0.7109])
recall = np.array([0.9995, 0.9991, 0.996, 0.9974, 0.9971, 0.9892, 0.9837, 0.9832, 0.9636, 0.5934])
f1 = np.array([0.9998, 0.9995, 0.998, 0.9987, 0.9986, 0.9946, 0.9918, 0.9915, 0.9814, 0.8310])
dataset_size = np.array([1, 0.8, 0.6, 0.4, 0.2, 0.1, 0.05, 0.025, 0.01, 0.005])
plt.figure(figsize=(8, 6))
plt.plot(dataset_size, precision, marker='o', label='Precision')
plt.plot(dataset_size, recall, marker='o', label='Recall')
plt.plot(dataset_size, f1, marker='o', label='F1 Score')

plt.xlabel('Dataset Size')
plt.xlim(0, 0.1)
plt.ylabel('Score')
plt.title('Precision vs Dataset Size: Seed 42')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig("16_4_8_Precision_42.png", dpi=300)
plt.show()

# %%
# 100 seed results
precision = np.array([0.9992, 0.9987, 0.9864, 0.9953, 0.9836, 0.7186, 0.7114])
recall = np.array([0.9992, 0.9987, 0.9862, 0.9953, 0.9833, 0.6085, 0.5944])
f1 = np.array([0.9996, 0.9993, 0.9932, 0.9977, 0.9917, 0.8363, 0.8314])
dataset_size = np.array([0.4, 0.2, 0.1, 0.05, 0.025, 0.01, 0.005])
plt.figure(figsize=(8, 6))
plt.plot(dataset_size, precision, marker='o', label='Precision')
plt.plot(dataset_size, recall, marker='o', label='Recall')
plt.plot(dataset_size, f1, marker='o', label='F1 Score')

plt.xlabel('Dataset Size')
plt.xlim(0, 0.1)
plt.ylabel('Score')
plt.title('Precision vs Dataset Size: Seed 100')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig("16_4_8_Precision_100.png", dpi=300)
plt.show()

# %%
# 22 seed results
precision = np.array([0.9991, 0.9972, 0.997, 0.9843, 0.9836, 0.5075, 0.7114])
recall = np.array([0.9991, 0.9972, 0.997, 0.9840, 0.9833, 0.0295, 0.5944])
f1 = np.array([0.9996, 0.9986, 0.9985, 0.9921, 0.99170, 0.6733, 0.8314])
dataset_size = np.array([0.4, 0.2, 0.1, 0.05, 0.025, 0.01, 0.005])
plt.figure(figsize=(8, 6))
plt.plot(dataset_size, precision, marker='o', label='Precision')
plt.plot(dataset_size, recall, marker='o', label='Recall')
plt.plot(dataset_size, f1, marker='o', label='F1 Score')

plt.xlabel('Dataset Size')
plt.xlim(0, 0.1)
plt.ylabel('Score')
plt.title('Precision vs Dataset Size: Seed 22')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig("16_4_8_Precision_22.png", dpi=300)
plt.show()

# %%
# 42 seed results
precision = np.array([0.9975, 0.9989, 0.9947, 0.9831, 0.9836, 0.7116, 0.7115])
recall =    np.array([0.9975, 0.9989, 0.9947, 0.9828, 0.9833, 0.5948, 0.5946])
f1        = np.array([0.9987, 0.9995, 0.9973, 0.9915, 0.9917, 0.8315, 0.8314])
dataset_size = np.array([0.4, 0.2, 0.1, 0.05, 0.025, 0.01, 0.005])
plt.figure(figsize=(8, 6))
plt.plot(dataset_size, precision, marker='o', label='Precision')
plt.plot(dataset_size, recall, marker='o', label='Recall')
plt.plot(dataset_size, f1, marker='o', label='F1 Score')

plt.xlabel('Dataset Size')
plt.xlim(0, 0.1)
plt.ylabel('Score')
plt.title('Precision vs Dataset Size: Seed 42')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig("32_16_4_8_Precision_Seed42.png", dpi=300)
plt.show()

# %%
precision = np.array([0.9989, 0.9990, 0.9804, 0.9836, 0.9838, 0.7116, 0.7116])
recall =    np.array([0.9989, 0.9990, 0.9800, 0.9833, 0.9835, 0.5947, 0.5947])
f1 =        np.array([0.9995, 0.9995, 0.9901, 0.9917, 0.9918, 0.8315, 0.8315])
dataset_size = np.array([0.4, 0.2, 0.1, 0.05, 0.025, 0.01, 0.005])

plt.figure(figsize=(8, 6))
plt.plot(dataset_size, precision, marker='o', label='Precision')
plt.plot(dataset_size, recall, marker='o', label='Recall')
plt.plot(dataset_size, f1, marker='o', label='F1 Score')

plt.xlabel('Dataset Size')
plt.xlim(0, 0.1)
plt.ylabel('Score')
plt.title('Precision vs Dataset Size: Seed 100')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig("32_16_4_8_Precision_Seed100.png", dpi=300)
plt.show()

# %%
precision = np.array([0.9983, 0.9974, 0.9835, 0.9860, 0.9837, 0.7116, 0.7114])
recall    = np.array([0.9983, 0.9974, 0.9832, 0.9858, 0.9834, 0.5947, 0.5944])
f1        = np.array([0.9992, 0.9987, 0.9917, 0.9929, 0.9918, 0.8315, 0.8314])
dataset_size = np.array([0.4, 0.2, 0.1, 0.05, 0.025, 0.01, 0.005])

plt.figure(figsize=(8, 6))
plt.plot(dataset_size, precision, marker='o', label='Precision')
plt.plot(dataset_size, recall, marker='o', label='Recall')
plt.plot(dataset_size, f1, marker='o', label='F1 Score')

plt.xlabel('Dataset Size')
plt.xlim(0, 0.1)
plt.ylabel('Score')
plt.title('Precision vs Dataset Size: Seed 22')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig("32_16_4_8_Precision_Seed22.png", dpi=300)
plt.show()
